# %%
import pandas as pd

# %%
file_path = "../data/raw/transactions-2026-09-03.csv"

# %%
df_sample = pd.read_csv(
    file_path,
    nrows=1000
)

# %%
df_sample.shape
# Out:
# (1000, 22)

# %%
df_sample.head()
# Out:
#   TRANSACTION_NUMBER        INSTANCE_DATE  GROUP_EN  \
# 0        101-10-2026  2026-07-01 16:00:21  Mortgage
# 1        101-10-2026  2026-07-01 16:00:21  Mortgage
# 2        101-10-2026  2026-07-01 16:00:21  Mortgage
# 3        101-10-2026  2026-07-01 16:00:21  Mortgage
# 4        101-11-2026  2026-07-01 16:29:02  Mortgage
#
#                                        PROCEDURE_EN IS_OFFPLAN_EN  \
# 0  Portfolio Mortgage Registration Pre-Registration      Off-Plan
# 1  Portfolio Mortgage Registration Pre-Registration      Off-Plan
# 2  Portfolio Mortgage Registration Pre-Registration      Off-Plan
# 3  Portfolio Mortgage Registration Pre-Registration      Off-Plan
# 4  Portfolio Mortgage Registration Pre-Registration      Off-Plan
#
#   IS_FREE_HOLD_EN     USAGE_EN       AREA_EN PROP_TYPE_EN PROP_SB_TYPE_EN  \
# 0       Free Hold  Residential  BUSINESS BAY         Unit            Flat
# 1       Free Hold  Residential  BUSINESS BAY         Unit            Flat
# ...

# %%
df_sample.columns
# Out:
# Index(['TRANSACTION_NUMBER', 'INSTANCE_DATE', 'GROUP_EN', 'PROCEDURE_EN',
#        'IS_OFFPLAN_EN', 'IS_FREE_HOLD_EN', 'USAGE_EN', 'AREA_EN',
#        'PROP_TYPE_EN', 'PROP_SB_TYPE_EN', 'TRANS_VALUE', 'PROCEDURE_AREA',
#        'ACTUAL_AREA', 'ROOMS_EN', 'PARKING', 'NEAREST_METRO_EN',
#        'NEAREST_MALL_EN', 'NEAREST_LANDMARK_EN', 'TOTAL_BUYER', 'TOTAL_SELLER',
#        'MASTER_PROJECT_EN', 'PROJECT_EN'],
#       dtype='str')

# %%
df_sample.dtypes
# Out:
# TRANSACTION_NUMBER         str
# INSTANCE_DATE              str
# GROUP_EN                   str
# PROCEDURE_EN               str
# IS_OFFPLAN_EN              str
# IS_FREE_HOLD_EN            str
# USAGE_EN                   str
# AREA_EN                    str
# PROP_TYPE_EN               str
# PROP_SB_TYPE_EN            str
# TRANS_VALUE            float64
# PROCEDURE_AREA         float64
# ACTUAL_AREA            float64
# ROOMS_EN                   str
# PARKING                    str
# NEAREST_METRO_EN           str
# NEAREST_MALL_EN            str
# NEAREST_LANDMARK_EN        str
# TOTAL_BUYER              int64
# TOTAL_SELLER             int64
# MASTER_PROJECT_EN          str
# PROJECT_EN                 str
# dtype: object

# %%
df_sample.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TRANSACTION_NUMBER   1000 non-null   str
#  1   INSTANCE_DATE        1000 non-null   str
#  2   GROUP_EN             1000 non-null   str
#  3   PROCEDURE_EN         1000 non-null   str
#  4   IS_OFFPLAN_EN        1000 non-null   str
#  5   IS_FREE_HOLD_EN      1000 non-null   str
#  6   USAGE_EN             1000 non-null   str
#  7   AREA_EN              1000 non-null   str
#  8   PROP_TYPE_EN         1000 non-null   str
#  9   PROP_SB_TYPE_EN      1000 non-null   str
#  10  TRANS_VALUE          1000 non-null   float64
#  11  PROCEDURE_AREA       1000 non-null   float64
#  12  ACTUAL_AREA          1000 non-null   float64
#  13  ROOMS_EN             956 non-null    str
#  14  PARKING              817 non-null    str
#  15  NEAREST_METRO_EN     488 non-null    str
# ...

# %%
df_sample.describe()
# Out:
#         TRANS_VALUE  PROCEDURE_AREA  ACTUAL_AREA  TOTAL_BUYER  TOTAL_SELLER
# count  1.000000e+03     1000.000000  1000.000000       1000.0        1000.0
# mean   2.618646e+06      110.163470   110.402090          0.0           0.0
# std    4.372980e+06       95.643301    95.597316          0.0           0.0
# min    1.566500e+05        3.730000     6.880000          0.0           0.0
# 25%    8.764992e+05       62.530000    62.530000          0.0           0.0
# 50%    1.573999e+06       81.650000    81.710000          0.0           0.0
# 75%    2.825000e+06      130.590000   131.467500          0.0           0.0
# max    7.156357e+07     1322.910000  1322.910000          0.0           0.0

# %%
df_sample.isna()
# Out:
#      TRANSACTION_NUMBER  INSTANCE_DATE  GROUP_EN  PROCEDURE_EN  IS_OFFPLAN_EN  \
# 0                 False          False     False         False          False
# 1                 False          False     False         False          False
# 2                 False          False     False         False          False
# 3                 False          False     False         False          False
# 4                 False          False     False         False          False
# ..                  ...            ...       ...           ...            ...
# 995               False          False     False         False          False
# 996               False          False     False         False          False
# 997               False          False     False         False          False
# 998               False          False     False         False          False
# 999               False          False     False         False          False
#
# ...

# %%
df_sample.isna().sum()
# Out:
# TRANSACTION_NUMBER       0
# INSTANCE_DATE            0
# GROUP_EN                 0
# PROCEDURE_EN             0
# IS_OFFPLAN_EN            0
# IS_FREE_HOLD_EN          0
# USAGE_EN                 0
# AREA_EN                  0
# PROP_TYPE_EN             0
# PROP_SB_TYPE_EN          0
# TRANS_VALUE              0
# PROCEDURE_AREA           0
# ACTUAL_AREA              0
# ROOMS_EN                44
# PARKING                183
# NEAREST_METRO_EN       512
# NEAREST_MALL_EN        525
# NEAREST_LANDMARK_EN    400
# TOTAL_BUYER              0
# TOTAL_SELLER             0
# MASTER_PROJECT_EN      997
# PROJECT_EN               0
# dtype: int64

# %%
missing_pct = df_sample.isna().mean() * 100

# %%
missing_pct
# Out:
# TRANSACTION_NUMBER      0.0
# INSTANCE_DATE           0.0
# GROUP_EN                0.0
# PROCEDURE_EN            0.0
# IS_OFFPLAN_EN           0.0
# IS_FREE_HOLD_EN         0.0
# USAGE_EN                0.0
# AREA_EN                 0.0
# PROP_TYPE_EN            0.0
# PROP_SB_TYPE_EN         0.0
# TRANS_VALUE             0.0
# PROCEDURE_AREA          0.0
# ACTUAL_AREA             0.0
# ROOMS_EN                4.4
# PARKING                18.3
# NEAREST_METRO_EN       51.2
# NEAREST_MALL_EN        52.5
# NEAREST_LANDMARK_EN    40.0
# TOTAL_BUYER             0.0
# TOTAL_SELLER            0.0
# MASTER_PROJECT_EN      99.7
# PROJECT_EN              0.0
# dtype: float64

# %%
df_sample["GROUP_EN"].value_counts()
# Out:
# GROUP_EN
# Sales       795
# Mortgage    205
# Name: count, dtype: int64

# %%
df_sample["PROCEDURE_EN"].value_counts()
# Out:
# PROCEDURE_EN
# Sell - Pre registration                             795
# Portfolio Mortgage Registration Pre-Registration    205
# Name: count, dtype: int64

# %%
for column in [
    "IS_OFFPLAN_EN",
    "IS_FREE_HOLD_EN",
    "USAGE_EN",
    "PROP_TYPE_EN",
    "PROP_SB_TYPE_EN"
]:
    print(f"\n--- {column} ---")
    print(df_sample[column].value_counts())
# Out:
# --- IS_OFFPLAN_EN ---
# IS_OFFPLAN_EN
# Off-Plan    1000
# Name: count, dtype: int64
#
# --- IS_FREE_HOLD_EN ---
# IS_FREE_HOLD_EN
# Free Hold    1000
# Name: count, dtype: int64
#
# --- USAGE_EN ---
# USAGE_EN
# Residential    1000
# Name: count, dtype: int64
#
# --- PROP_TYPE_EN ---
# PROP_TYPE_EN
# Unit        842
# Building    158
# Name: count, dtype: int64
#
# --- PROP_SB_TYPE_EN ---
# PROP_SB_TYPE_EN
# Flat               781
# Villa              158
# Office              35
# Hotel Apartment     13
# Shop                 9
# Hotel Rooms          4
# Name: count, dtype: int64

# %%
df_sample["PROP_SB_TYPE_EN"].value_counts().to_string()
# Out:
# 'PROP_SB_TYPE_EN\nFlat               781\nVilla              158\nOffice              35\nHotel Apartment     13\nShop                 9\nHotel Rooms          4'

# %%
df_sample[
    [
        "TRANS_VALUE",
        "PROCEDURE_AREA",
        "ACTUAL_AREA",
        "TOTAL_BUYER",
        "TOTAL_SELLER"
    ]
].describe()
# Out:
#         TRANS_VALUE  PROCEDURE_AREA  ACTUAL_AREA  TOTAL_BUYER  TOTAL_SELLER
# count  1.000000e+03     1000.000000  1000.000000       1000.0        1000.0
# mean   2.618646e+06      110.163470   110.402090          0.0           0.0
# std    4.372980e+06       95.643301    95.597316          0.0           0.0
# min    1.566500e+05        3.730000     6.880000          0.0           0.0
# 25%    8.764992e+05       62.530000    62.530000          0.0           0.0
# 50%    1.573999e+06       81.650000    81.710000          0.0           0.0
# 75%    2.825000e+06      130.590000   131.467500          0.0           0.0
# max    7.156357e+07     1322.910000  1322.910000          0.0           0.0

# %%
df_sample[["TOTAL_BUYER", "TOTAL_SELLER"]].value_counts()
# Out:
# TOTAL_BUYER  TOTAL_SELLER
# 0            0               1000
# Name: count, dtype: int64

# %%
df_sample["INSTANCE_DATE"].head(10)
# Out:
# 0    2026-07-01 16:00:21
# 1    2026-07-01 16:00:21
# 2    2026-07-01 16:00:21
# 3    2026-07-01 16:00:21
# 4    2026-07-01 16:29:02
# 5    2026-07-01 16:29:02
# 6    2026-07-01 16:29:02
# 7    2026-07-01 16:29:02
# 8    2026-07-01 16:12:45
# 9    2026-07-01 16:12:45
# Name: INSTANCE_DATE, dtype: str

# %%
df_sample["TRANSACTION_NUMBER"].nunique()
# Out:
# 811

# %%
df_sample["TRANSACTION_NUMBER"].value_counts().value_counts()
# Out:
# count
# 1     795
# 4       4
# 12      2
# 6       2
# 3       2
# 80      1
# 27      1
# 15      1
# 13      1
# 7       1
# 5       1
# Name: count, dtype: int64

# %%
transaction_counts = df_sample["TRANSACTION_NUMBER"].value_counts()

transaction_counts[transaction_counts > 20]
# Out:
# TRANSACTION_NUMBER
# 101-3-2026    80
# 101-6-2026    27
# Name: count, dtype: int64

# %%
df_sample[df_sample["TRANSACTION_NUMBER"] == "101-3-2026"]
# Out:
#     TRANSACTION_NUMBER        INSTANCE_DATE  GROUP_EN  \
# 48          101-3-2026  2026-03-23 14:53:48  Mortgage
# 49          101-3-2026  2026-03-23 14:53:48  Mortgage
# 50          101-3-2026  2026-03-23 14:53:48  Mortgage
# 51          101-3-2026  2026-03-23 14:53:48  Mortgage
# 52          101-3-2026  2026-03-23 14:53:48  Mortgage
# ..                 ...                  ...       ...
# 123         101-3-2026  2026-03-23 14:53:48  Mortgage
# 124         101-3-2026  2026-03-23 14:53:48  Mortgage
# 125         101-3-2026  2026-03-23 14:53:48  Mortgage
# 126         101-3-2026  2026-03-23 14:53:48  Mortgage
# 127         101-3-2026  2026-03-23 14:53:48  Mortgage
#
#                                          PROCEDURE_EN IS_OFFPLAN_EN  \
# 48   Portfolio Mortgage Registration Pre-Registration      Off-Plan
# 49   Portfolio Mortgage Registration Pre-Registration      Off-Plan
# 50   Portfolio Mortgage Registration Pre-Registration      Off-Plan
# ...

# %%
df_sample.duplicated().sum()
# Out:
# np.int64(99)

# %%
df_sample.drop_duplicates().shape
# Out:
# (901, 22)

# %%
df_sample.nunique()
# Out:
# TRANSACTION_NUMBER     811
# INSTANCE_DATE          806
# GROUP_EN                 2
# PROCEDURE_EN             2
# IS_OFFPLAN_EN            1
# IS_FREE_HOLD_EN          1
# USAGE_EN                 1
# AREA_EN                 72
# PROP_TYPE_EN             2
# PROP_SB_TYPE_EN          6
# TRANS_VALUE            705
# PROCEDURE_AREA         696
# ACTUAL_AREA            702
# ROOMS_EN                 7
# PARKING                 38
# NEAREST_METRO_EN        25
# NEAREST_MALL_EN          5
# NEAREST_LANDMARK_EN     10
# TOTAL_BUYER              1
# TOTAL_SELLER             1
# MASTER_PROJECT_EN        1
# PROJECT_EN             271
# dtype: int64

# %%
df_sample.memory_usage(deep=True).sum()
# Out:
# np.int64(1000274)

# %%
with open(file_path, "r", encoding="utf-8") as f:
    row_count = sum(1 for _ in f) - 1

row_count
# Out:
# 148625

# %%
df = pd.read_csv(file_path)

df.shape
# Out:
# (148591, 22)

# %%
df.memory_usage(deep=True).sum() / (1024 ** 2)
# Out:
# np.float64(139.26946258544922)

# %%
missing = df.isna().sum()

missing_pct = (df.isna().mean() * 100).round(2)

pd.DataFrame({
    "missing_count": missing,
    "missing_pct": missing_pct
}).sort_values("missing_count", ascending=False)
# Out:
#                      missing_count  missing_pct
# MASTER_PROJECT_EN           148066        99.65
# NEAREST_MALL_EN              78058        52.53
# NEAREST_METRO_EN             76411        51.42
# NEAREST_LANDMARK_EN          57790        38.89
# PARKING                      32927        22.16
# ROOMS_EN                     21126        14.22
# PROJECT_EN                   18943        12.75
# PROP_SB_TYPE_EN               1886         1.27
# PROCEDURE_AREA                   4         0.00
# IS_OFFPLAN_EN                    0         0.00
# INSTANCE_DATE                    0         0.00
# TRANSACTION_NUMBER               0         0.00
# PROCEDURE_EN                     0         0.00
# GROUP_EN                         0         0.00
# IS_FREE_HOLD_EN                  0         0.00
# ACTUAL_AREA                      0         0.00
# AREA_EN                          0         0.00
# PROP_TYPE_EN                     0         0.00
# USAGE_EN                         0         0.00
# ...

# %%
categorical_cols = [
    "GROUP_EN",
    "PROCEDURE_EN",
    "IS_OFFPLAN_EN",
    "IS_FREE_HOLD_EN",
    "USAGE_EN",
    "PROP_TYPE_EN",
    "PROP_SB_TYPE_EN"
]

for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df[col].value_counts(dropna=False))
# Out:
# --- GROUP_EN ---
# GROUP_EN
# Sales       112033
# Mortgage     30658
# Gifts         5900
# Name: count, dtype: int64
#
# --- PROCEDURE_EN ---
# PROCEDURE_EN
# Sell - Pre registration                             75147
# Sale                                                26033
# Mortgage Registration                               20465
# Delayed Sell                                         7590
# Grant                                                4547
# Delayed Mortgage                                     2852
# Portfolio Mortgage Registration                      2817
# Development Registration Pre-Registration            1468
# Modify Mortgage                                      1145
# Portfolio Mortgage Modification                      1095
# Grant Pre-Registration                                883
# Lease to Own Registration                             818
# Sell Development                                      703
# ...

# %%
categorical_cols = df.select_dtypes(include="object").columns
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_40252\3906971751.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include="object").columns

# %%
df[categorical_cols].nunique().sort_values(ascending=False)
# Out:
# TRANSACTION_NUMBER     143955
# INSTANCE_DATE          141659
# PARKING                 14958
# PROJECT_EN               2986
# AREA_EN                   272
# NEAREST_METRO_EN           55
# PROCEDURE_EN               39
# PROP_SB_TYPE_EN            37
# ROOMS_EN                   13
# NEAREST_LANDMARK_EN        13
# MASTER_PROJECT_EN          10
# NEAREST_MALL_EN             5
# GROUP_EN                    3
# PROP_TYPE_EN                3
# IS_FREE_HOLD_EN             2
# IS_OFFPLAN_EN               2
# USAGE_EN                    2
# dtype: int64

# %%
df.describe().T
# Out:
#                    count          mean           std     min        25%  \
# TRANS_VALUE     148591.0  3.523551e+06  3.627088e+07  163.35  814777.00
# PROCEDURE_AREA  148587.0  4.136656e+02  2.450779e+04    0.75      58.16
# ACTUAL_AREA     148591.0  4.985328e+02  3.218817e+04    6.55      59.41
# TOTAL_BUYER     148591.0  0.000000e+00  0.000000e+00    0.00       0.00
# TOTAL_SELLER    148591.0  0.000000e+00  0.000000e+00    0.00       0.00
#
#                        50%         75%           max
# TRANS_VALUE     1407810.80  2711040.00  1.034807e+10
# PROCEDURE_AREA       84.50      144.04  6.718307e+06
# ACTUAL_AREA          85.39      144.36  6.718634e+06
# TOTAL_BUYER           0.00        0.00  0.000000e+00
# TOTAL_SELLER          0.00        0.00  0.000000e+00

# %%
df.nlargest(10, "TRANS_VALUE")[
    [
        "TRANSACTION_NUMBER",
        "INSTANCE_DATE",
        "GROUP_EN",
        "PROCEDURE_EN",
        "TRANS_VALUE",
        "ACTUAL_AREA",
        "AREA_EN",
        "PROP_TYPE_EN",
        "PROP_SB_TYPE_EN",
        "PROJECT_EN"
    ]
]
# Out:
#        TRANSACTION_NUMBER        INSTANCE_DATE  GROUP_EN  \
# 129253         39-66-2026  2026-01-28 11:14:00  Mortgage
# 118191        13-385-2026  2026-01-06 15:39:24  Mortgage
# 140615        460-53-2026  2026-01-23 21:04:05     Sales
# 125004        14-677-2026  2026-05-13 16:39:45  Mortgage
# 120473       13-6126-2026  2026-02-26 10:31:31  Mortgage
# 94327        11-3159-2026  2026-01-23 23:12:55     Sales
# 115734       13-2281-2026  2026-01-23 23:14:20  Mortgage
# 140616        460-54-2026  2026-01-23 21:01:01     Sales
# 131631       41-2665-2026  2026-02-11 12:38:36     Sales
# 125566         152-2-2026  2026-05-19 08:31:45  Mortgage
#
#                                        PROCEDURE_EN   TRANS_VALUE  \
# 129253                         Development Mortgage  1.034807e+10
# 118191                        Mortgage Registration  4.250000e+09
# 140615                         Sale On Payment Plan  3.130255e+09
# 125004                              Modify Mortgage  2.594830e+09
# ...

# %%
(df[[
    "TRANS_VALUE",
    "PROCEDURE_AREA",
    "ACTUAL_AREA"
]] <= 0).sum()
# Out:
# TRANS_VALUE       0
# PROCEDURE_AREA    0
# ACTUAL_AREA       0
# dtype: int64

# %%
df["PRICE_PER_SQM"] = df["TRANS_VALUE"] / df["ACTUAL_AREA"]

df["PRICE_PER_SQM"].describe()
# Out:
# count    1.485910e+05
# mean     1.873712e+04
# std      1.330045e+04
# min      1.905623e+00
# 25%      1.253616e+04
# 50%      1.718138e+04
# 75%      2.218777e+04
# max      2.207993e+06
# Name: PRICE_PER_SQM, dtype: float64

# %%
df.nsmallest(10, "PRICE_PER_SQM")[
    [
        "TRANSACTION_NUMBER",
        "GROUP_EN",
        "PROCEDURE_EN",
        "TRANS_VALUE",
        "ACTUAL_AREA",
        "PRICE_PER_SQM",
        "AREA_EN",
        "PROP_TYPE_EN",
        "PROP_SB_TYPE_EN",
        "PROJECT_EN"
    ]
]
# Out:
#        TRANSACTION_NUMBER GROUP_EN              PROCEDURE_EN  TRANS_VALUE  \
# 90162       11-23384-2026    Sales                      Sale       163.35
# 79606       11-13620-2026    Sales                      Sale     89125.08
# 124039       133-272-2026    Sales  Development Registration     51958.00
# 124041       133-274-2026    Sales  Development Registration     65672.00
# 124049       133-282-2026    Sales  Development Registration     92161.00
# 124044       133-277-2026    Sales  Development Registration    111869.00
# 124046       133-279-2026    Sales  Development Registration     42373.00
# 124042       133-275-2026    Sales  Development Registration     77441.00
# 124043       133-276-2026    Sales  Development Registration     77383.00
# 124038       133-271-2026    Sales  Development Registration     42374.00
#
#         ACTUAL_AREA  PRICE_PER_SQM                      AREA_EN PROP_TYPE_EN  \
# ...

# %%
df.nlargest(10, "PRICE_PER_SQM")[
    [
        "TRANSACTION_NUMBER",
        "GROUP_EN",
        "PROCEDURE_EN",
        "TRANS_VALUE",
        "ACTUAL_AREA",
        "PRICE_PER_SQM",
        "AREA_EN",
        "PROP_TYPE_EN",
        "PROP_SB_TYPE_EN",
        "PROJECT_EN"
    ]
]
# Out:
#        TRANSACTION_NUMBER  GROUP_EN              PROCEDURE_EN   TRANS_VALUE  \
# 123997       133-228-2026     Sales  Development Registration  1.000000e+08
# 124826        14-505-2026  Mortgage           Modify Mortgage  1.718724e+08
# 124045       133-278-2026     Sales  Development Registration  1.000000e+08
# 124109       133-477-2025     Sales  Development Registration  3.826770e+07
# 32717      102-39311-2026     Sales   Sell - Pre registration  1.176556e+08
# 83038       11-16803-2026     Sales                      Sale  1.100000e+09
# 124445        14-135-2020  Mortgage           Modify Mortgage  3.000000e+07
# 74669       102-9383-2026     Sales   Sell - Pre registration  2.699100e+07
# 99014        11-7491-2026     Sales                      Sale  3.200000e+08
# 107463      13-14077-2026  Mortgage     Mortgage Registration  7.700000e+08
#
#         ACTUAL_AREA  PRICE_PER_SQM                      AREA_EN PROP_TYPE_EN  \
# ...

# %%
df.nsmallest(10, "PRICE_PER_SQM")[
    [
        "TRANSACTION_NUMBER",
        "GROUP_EN",
        "PROCEDURE_EN",
        "TRANS_VALUE",
        "ACTUAL_AREA",
        "PRICE_PER_SQM",
        "AREA_EN",
        "PROP_TYPE_EN",
        "PROP_SB_TYPE_EN",
        "PROJECT_EN"
    ]
]
# Out:
#        TRANSACTION_NUMBER GROUP_EN              PROCEDURE_EN  TRANS_VALUE  \
# 90162       11-23384-2026    Sales                      Sale       163.35
# 79606       11-13620-2026    Sales                      Sale     89125.08
# 124039       133-272-2026    Sales  Development Registration     51958.00
# 124041       133-274-2026    Sales  Development Registration     65672.00
# 124049       133-282-2026    Sales  Development Registration     92161.00
# 124044       133-277-2026    Sales  Development Registration    111869.00
# 124046       133-279-2026    Sales  Development Registration     42373.00
# 124042       133-275-2026    Sales  Development Registration     77441.00
# 124043       133-276-2026    Sales  Development Registration     77383.00
# 124038       133-271-2026    Sales  Development Registration     42374.00
#
#         ACTUAL_AREA  PRICE_PER_SQM                      AREA_EN PROP_TYPE_EN  \
# ...

# %%
df.shape
# Out:
# (148591, 23)

# %%
df.duplicated().sum()
# Out:
# np.int64(190)

# %%
df[df.duplicated(keep=False)].sort_values("TRANSACTION_NUMBER").head(20)
# Out:
#     TRANSACTION_NUMBER        INSTANCE_DATE  GROUP_EN  \
# 8          101-12-2026  2026-07-01 16:12:45  Mortgage
# 10         101-12-2026  2026-07-01 16:12:45  Mortgage
# 12         101-12-2026  2026-07-01 16:12:45  Mortgage
# 13         101-12-2026  2026-07-01 16:12:45  Mortgage
# 14         101-12-2026  2026-07-01 16:12:45  Mortgage
# 19         101-14-2026  2026-07-07 09:54:50  Mortgage
# 24         101-14-2026  2026-07-07 09:54:50  Mortgage
# 34         101-15-2026  2026-07-03 09:22:23  Mortgage
# 33         101-15-2026  2026-07-03 09:22:23  Mortgage
# 99          101-3-2026  2026-03-23 14:53:48  Mortgage
# 106         101-3-2026  2026-03-23 14:53:48  Mortgage
# 104         101-3-2026  2026-03-23 14:53:48  Mortgage
# 103         101-3-2026  2026-03-23 14:53:48  Mortgage
# 102         101-3-2026  2026-03-23 14:53:48  Mortgage
# 101         101-3-2026  2026-03-23 14:53:48  Mortgage
# 100         101-3-2026  2026-03-23 14:53:48  Mortgage
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(190)

# %%
df = df.drop_duplicates().copy()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (148401, 23)

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# MASTER_PROJECT_EN      147876
# NEAREST_MALL_EN         78038
# NEAREST_METRO_EN        76391
# NEAREST_LANDMARK_EN     57780
# PARKING                 32833
# ROOMS_EN                21117
# PROJECT_EN              18889
# PROP_SB_TYPE_EN          1886
# PROCEDURE_AREA              4
# IS_OFFPLAN_EN               0
# IS_FREE_HOLD_EN             0
# GROUP_EN                    0
# INSTANCE_DATE               0
# TRANSACTION_NUMBER          0
# PROCEDURE_EN                0
# USAGE_EN                    0
# AREA_EN                     0
# PROP_TYPE_EN                0
# TRANS_VALUE                 0
# ACTUAL_AREA                 0
# TOTAL_BUYER                 0
# TOTAL_SELLER                0
# PRICE_PER_SQM               0
# dtype: int64

# %%
df = df.drop(columns=["MASTER_PROJECT_EN"])

# %%
df.shape
# Out:
# (148401, 22)

# %%
df[df["ROOMS_EN"].isna()]["PROP_SB_TYPE_EN"].value_counts(dropna=False)
# Out:
# PROP_SB_TYPE_EN
# Residential                           7766
# Commercial                            4491
# Office                                2386
# NaN                                   1886
# Shop                                  1303
# General Use                            775
# Residential / Residential Villa        601
# Land                                   341
# Airport                                296
# Government Housing                     253
# Residential Flats                      225
# Industrial                             214
# Villa                                  203
# Residential / Villas                   145
# Labor Camp                              51
# Residential / Attached Villas           41
# Unit                                    27
# Sports Club                             20
# Agricultural                            14
# Workshop                                14
# Warehouse                               14
# ...

# %%
df[
    (df["ROOMS_EN"].isna()) &
    (df["PROP_SB_TYPE_EN"].isin([
        "Flat",
        "Villa",
        "Residential",
        "Residential Flats"
    ]))
]["PROP_SB_TYPE_EN"].value_counts()
# Out:
# PROP_SB_TYPE_EN
# Residential          7766
# Residential Flats     225
# Villa                 203
# Flat                    4
# Name: count, dtype: int64

# %%
df["ROOMS_EN"].value_counts(dropna=False)
# Out:
# ROOMS_EN
# 1 B/R        45430
# Studio       31627
# 2 B/R        28145
# NaN          21117
# 3 B/R        11355
# 4 B/R         6678
# Office        1946
# 5 B/R         1710
# Shop           270
# 6 B/R           71
# PENTHOUSE       36
# 7 B/R           13
# 9 B/R            2
# Hotel            1
# Name: count, dtype: int64

# %%
categorical_missing_cols = [
    "ROOMS_EN",
    "PARKING",
    "NEAREST_METRO_EN",
    "NEAREST_MALL_EN",
    "NEAREST_LANDMARK_EN",
    "PROJECT_EN",
    "PROP_SB_TYPE_EN"
]

df[categorical_missing_cols] = df[categorical_missing_cols].fillna("Unknown")

# %%
df[categorical_missing_cols].isna().sum()
# Out:
# ROOMS_EN               0
# PARKING                0
# NEAREST_METRO_EN       0
# NEAREST_MALL_EN        0
# NEAREST_LANDMARK_EN    0
# PROJECT_EN             0
# PROP_SB_TYPE_EN        0
# dtype: int64

# %%
df[df["PROCEDURE_AREA"].isna()][
    ["PROCEDURE_AREA", "ACTUAL_AREA", "TRANS_VALUE", "AREA_EN", "PROP_TYPE_EN"]
]
# Out:
#         PROCEDURE_AREA  ACTUAL_AREA   TRANS_VALUE         AREA_EN PROP_TYPE_EN
# 93696              NaN        70.14  1.480000e+06      THE GREENS         Unit
# 125566             NaN   6718633.78  1.311384e+09    Saih Aldahal         Land
# 125567             NaN   4478819.00  1.311384e+09    Saih Aldahal         Land
# 137096             NaN       187.94  3.645455e+06  BARSHA HEIGHTS         Unit

# %%
df["PROCEDURE_AREA"].isna().sum()
# Out:
# np.int64(4)

# %%
df.isna().sum().sort_values(ascending=False).head(10)
# Out:
# PROCEDURE_AREA        4
# TRANSACTION_NUMBER    0
# GROUP_EN              0
# PROCEDURE_EN          0
# IS_OFFPLAN_EN         0
# INSTANCE_DATE         0
# IS_FREE_HOLD_EN       0
# USAGE_EN              0
# PROP_TYPE_EN          0
# AREA_EN               0
# dtype: int64

# %%
df["PROCEDURE_AREA"] = df["PROCEDURE_AREA"].fillna(df["ACTUAL_AREA"])

# %%
df["PROCEDURE_AREA"].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sort_values(ascending=False).head(10)
# Out:
# TRANSACTION_NUMBER    0
# INSTANCE_DATE         0
# GROUP_EN              0
# PROCEDURE_EN          0
# IS_OFFPLAN_EN         0
# IS_FREE_HOLD_EN       0
# USAGE_EN              0
# AREA_EN               0
# PROP_TYPE_EN          0
# PROP_SB_TYPE_EN       0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df["INSTANCE_DATE"] = pd.to_datetime(df["INSTANCE_DATE"])

# %%
df["INSTANCE_DATE"].dtype
# Out:
# dtype('<M8[us]')

# %%
df["YEAR"] = df["INSTANCE_DATE"].dt.year
df["MONTH"] = df["INSTANCE_DATE"].dt.month
df["DAY_OF_WEEK"] = df["INSTANCE_DATE"].dt.dayofweek

# %%
df[["INSTANCE_DATE", "YEAR", "MONTH", "DAY_OF_WEEK"]].head()
# Out:
#         INSTANCE_DATE  YEAR  MONTH  DAY_OF_WEEK
# 0 2026-07-01 16:00:21  2026      7            2
# 1 2026-07-01 16:00:21  2026      7            2
# 2 2026-07-01 16:00:21  2026      7            2
# 3 2026-07-01 16:00:21  2026      7            2
# 4 2026-07-01 16:29:02  2026      7            2

# %%
df[["TRANS_VALUE", "ACTUAL_AREA", "PRICE_PER_SQM"]].head()
# Out:
#    TRANS_VALUE  ACTUAL_AREA  PRICE_PER_SQM
# 0   1699451.22        46.17   36808.560104
# 1   1699451.22        99.32   17110.866089
# 2   1699451.22        91.81   18510.524126
# 3   1699451.22        46.15   36824.511809
# 4   6608107.80       535.68   12335.924059

# %%
df = df.drop(columns=[
    "TRANSACTION_NUMBER",
    "INSTANCE_DATE",
    "TOTAL_BUYER",
    "TOTAL_SELLER"
])

# %%
df.shape
# Out:
# (148401, 21)

# %%
df.columns
# Out:
# Index(['GROUP_EN', 'PROCEDURE_EN', 'IS_OFFPLAN_EN', 'IS_FREE_HOLD_EN',
#        'USAGE_EN', 'AREA_EN', 'PROP_TYPE_EN', 'PROP_SB_TYPE_EN', 'TRANS_VALUE',
#        'PROCEDURE_AREA', 'ACTUAL_AREA', 'ROOMS_EN', 'PARKING',
#        'NEAREST_METRO_EN', 'NEAREST_MALL_EN', 'NEAREST_LANDMARK_EN',
#        'PROJECT_EN', 'PRICE_PER_SQM', 'YEAR', 'MONTH', 'DAY_OF_WEEK'],
#       dtype='str')

# %%
categorical_cols = df.select_dtypes(include="object").columns
categorical_cols
# Out:
# C:\Users\gagan\AppData\Local\Temp\ipykernel_40252\3430876840.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include="object").columns
# Index(['GROUP_EN', 'PROCEDURE_EN', 'IS_OFFPLAN_EN', 'IS_FREE_HOLD_EN',
#        'USAGE_EN', 'AREA_EN', 'PROP_TYPE_EN', 'PROP_SB_TYPE_EN', 'ROOMS_EN',
#        'PARKING', 'NEAREST_METRO_EN', 'NEAREST_MALL_EN', 'NEAREST_LANDMARK_EN',
#        'PROJECT_EN'],
#       dtype='str')

# %%
categorical_cols = df.select_dtypes(include="str").columns

# %%
numerical_cols = df.select_dtypes(include="number").columns
numerical_cols
# Out:
# Index(['TRANS_VALUE', 'PROCEDURE_AREA', 'ACTUAL_AREA', 'PRICE_PER_SQM', 'YEAR',
#        'MONTH', 'DAY_OF_WEEK'],
#       dtype='str')

# %%
y = df["TRANS_VALUE"]

# %%
X = df.drop(columns=["TRANS_VALUE", "PRICE_PER_SQM"])
y = df["TRANS_VALUE"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (148401, 19)
# (148401,)

# %%
df.to_csv("../data/processed/cleaned_transactions.csv", index=False)

# %%
import os

os.path.exists("../data/processed/cleaned_transactions.csv")
# Out:
# True
